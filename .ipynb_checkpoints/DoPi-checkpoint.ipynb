# %%
import pandas as pd

# %%
df = pd.read_csv("results.csv", encoding="latin-1", low_memory=False)

# %%
df.columns
# Out:
# Index(['Authors', 'Title', 'Journal', 'Pub Year', 'Pub Vol', 'DOI',
#        'Methodology', 'Pollinator Survey', 'Plant Survey',
#        'NBN Pollinator Code', 'COL Pollinator Code', 'Pollinator Species',
#        'Caste', 'NBN Plant Code', 'COL Plant Code', 'Plant Species',
#        'Interactions', 'Date', 'Month', 'Year', 'Grid Letter', 'Grid Code',
#        'Latitude', 'Longitude', 'Habitat', 'Pollination', 'Pollen', 'Nectar',
#        'Record', 'ArticleURL'],
#       dtype='object')

# %%
df.head()
# Out:
#                Authors                                              Title  \
# 0   M. L. Forup et al.  The restoration of plant-pollinator interactio...
# 1   M. L. Forup et al.  The restoration of plant-pollinator interactio...
# 2  R. E. Fowler et al.  Floral abundance and resource quality influenc...
# 3   M. L. Forup et al.  The restoration of plant-pollinator interactio...
# 4   M. L. Forup et al.  The restoration of plant-pollinator interactio...
#
#                              Journal  Pub Year  Pub Vol  \
# 0                Restoration Ecology    2005.0     13.0
# 1                Restoration Ecology    2005.0     13.0
# 2  Insect Conservation and Diversity    2016.0      9.0
# 3                Restoration Ecology    2005.0     13.0
# 4                Restoration Ecology    2005.0     13.0
#
#                                 DOI Methodology Pollinator Survey  \
# 0  10.1111/j.1526-100X.2005.00034.x          DO               All
# ...

# %%
df = df[['Pollinator Species','Plant Species','Interactions']]
df.head()
# Out:
#         Pollinator Species       Plant Species  Interactions
# 0        Euclidia glyphica    Ranunculus acris           1.0
# 1     Zygaena filipendulae    Knautia arvensis           1.0
# 2            Eristalis sp.  Crataegus monogyna           1.0
# 3   Platycheirus albimanus    Ranunculus acris           1.0
# 4  Platycheirus angustatus    Senecio jacobaea           1.0
